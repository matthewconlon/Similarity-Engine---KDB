# %% [markdown]
# # 01 - Data Acquisition
#
# This notebook explains how to collect **StatsBomb Open Data** for the Peak KDB similarity engine.
#
# > Goal: automate public football data ingestion for a reproducible hackathon workflow.

# %% [markdown]
# ## Why this matters
#
# We are **not** predicting the best football player.
# We are creating an **archetype** and searching for similar entities in feature space.

# %%
from pathlib import Path
import sys

sys.path.append(str(Path('..').resolve() / 'src'))
from download_statsbomb_data import download_all

raw_dir = Path('../data/raw')
download_all(raw_dir, limit_matches=None)

# %% [markdown]
# ## Inspect the downloaded structure
#
# - `competitions.json`
# - `matches/`
# - `events/`
# - `lineups/`
